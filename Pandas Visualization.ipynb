# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/Users/asmaabdallah/Downloads/Ice Cream Ratings-2.csv')
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind ='line', subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind='line', title='Ice Ceam Ratings', xlabel='Daily Ratings', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Ceam Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind='bar', x='Date', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked= True)
# Out:
# <Axes: >

# %%
df.plot.scatter(x='Texture Rating', y='Overall Rating', s=500, c='Yellow')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(x='Date', figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Flavor Rating', figsize=(20,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
